# %%
import requests
from lxml import html
import pandas as pd
import json
import md5
import httplib, httplib2
import numpy as np
# Out:
# /Users/jackdwyer/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: DeprecationWarning: the md5 module is deprecated; use hashlib instead

# %% [markdown]
# # In addition to an Authorization header, requests to the Connect API should
# # include the indicated Accept and Content-Type headers.
#
# # Send a GET request to the ListLocations endpoint and obtain the response.
# connection = httplib.HTTPSConnection('http://soundcloud.com/jack-dwyer-9')
# request_path = '/followers'
# connection.request('GET', request_path, '', request_headers)
# response = connection.getresponse()

# %%
artist = 'darien-fields'
start_urls = 'https://soundcloud.com/%s' % artist
CLIENT_ID='5de9fa406c6bd4d7076fe0678c95d9be'


url = 'http://api.soundcloud.com/resolve'
response = requests.get(url, params = {'url':start_urls, 'client_id':CLIENT_ID}).json()
   


ident = str(response['id'])
url2 = 'http://api.soundcloud.com/users/%s/followers' % ident
response2 = requests.get(url2, params = {'client_id':CLIENT_ID}).json()

next_href = response2.get('next_href',None)

    
follow_list = []
while next_href is not None:
    follow_list.extend(response2['collection'])
    response2 = requests.get(next_href).json()
    next_href = response2.get('next_href', None)

#store 10000 entries, then save, then do again and append
#2 files, user info and user followers (timestamped) all in one over arching artist file

# %%
print follow_list
# Out:
# [{u'website': None, u'myspace_name': None, u'last_name': u'', u'reposts_count': 0, u'public_favorites_count': 0, u'followings_count': 370, u'full_name': u'Claire', u'id': 188658331, u'city': u'Bruxelles', u'first_name': u'Claire', u'track_count': 6, u'playlist_count': 0, u'discogs_name': None, u'followers_count': 306, u'online': False, u'username': u'Claire13', u'description': u'17 ans', u'permalink': u'clxire13', u'last_modified': u'2017/07/15 10:00:08 +0000', u'plan': u'Free', u'permalink_url': u'http://soundcloud.com/clxire13', u'likes_count': 0, u'kind': u'user', u'country': u'Belgium', u'uri': u'https://api.soundcloud.com/users/188658331', u'avatar_url': u'https://i1.sndcdn.com/avatars-000323114873-x3a0h4-large.jpg', u'comments_count': 9, u'website_title': None}, {u'website': u'https://archive.org/details/cior-103-zachary-zena-giberson-david-m-paganin-vacua-for-a-lost-millenium-ep', u'myspace_name': None, u'last_name': u'Paganin', u'reposts_count': 1, u'public_favorites_count': 0, u'followings_count': 1121, u'full_name': u'David Paganin', u'id': 213250644, u'city': u'West Footscray, Melbourne', u'first_name': u'David', u'track_count': 29, u'playlist_count': 0, u'discogs_name': u'5662051-David-M-Paganin', u'followers_count': 953, u'online': False, u'username': u'David M. Paganin', u'description': u'I love making my own music.\n\nThe expressive themes that interest me typically pertain to human freedom in a post-modern world. Such themes include alienation, psychological repression, the existential vacuum, obsession, rage, absurdity, mourning, regret, neurosis, depression, death and the concept of self.  These themes may be bleak, yet all sounds are intended to be ultimately uplifting affirmations of human vitality and spirit.\n\nInfluences range from old-school industrial to musique concr\xe8te and contemporary classical, from kosmische musik to minimalism and dada, from power electronics to any form of genuinely experimental music.  While absorbing and acknowledging these influences, it is important to me to find and evolve my own sound.  \n\nBesides making my own music, my major interests are physics research, literature, psychology and gardening.\n\nContact: david.paganin@gmail.com', u'permalink': u'david-paganin', u'last_modified': u'2017/07/07 00:04:25 +0000', u'plan': u'Free', u'permalink_url': u'http://soundcloud.com/david-paganin', u'likes_count': 0, u'kind': u'user', u'country': u'Australia', u'uri': u'https://api.soundcloud.com/users/213250644', u'avatar_url': u'https://i1.sndcdn.com/avatars-000237172066-uw1zr7-large.jpg', u'comments_count': 5547, u'website_title': u'Giberson/Paganin EP on Cian Orbe (2017)'}, {u'website': u'http://www.worldstarbangerz.com/', u'myspace_name': None, u'last_name': u'', u'reposts_count': 0, u'public_favorites_count': 0, u'followings_count': 1014, u'full_name': u'', u'id': 35362637, u'city': u'', u'first_name': u'', u'track_count': 12, u'playlist_count': 0, u'discogs_name': None, u'followers_count': 1044, u'online': False, u'username': u'WorldStarBangerz', u'description': u'Collabs:\nsubmit@worldstarbangerz.com \n\nRequirements\n*Zipped loop \n*Official Tag of yours\n\nDaw \n*Fl Studio\n\nGenre\n*No Genre', u'permalink': u'worldstarbangerz', u'last_modified': u'2017/07/25 14:21:34 +0000', u'plan': u'Free', u'permalink_url': u'http://soundcloud.com/worldstarbangerz', u'likes_count': 0, u'kind': u'user', u'country': None, u'uri': u'https://api.soundcloud.com/users/35362637', u'avatar_url': u'https://i1.sndcdn.com/avatars-000325862107-mm30zu-large.jpg', u'comments_count': 714, u'website_title': u'Web'}, {u'website': u'https://youtu.be/IEvQOOecl88', u'myspace_name': None, u'last_name': u'', u'reposts_count': 0, u'public_favorites_count': 0, u'followings_count': 568, u'full_name': u'', u'id': 208480629, u'city': None, u'first_name': u'', u'track_count': 2, u'playlist_count': 0, u'discogs_name': None, u'followers_count': 661, u'online': False, u'username': u'Cold Mantra', u'description': u" ...

# %%
with open('follow_%s.json' %artist, 'a') as f:
    f.write(json.dumps(follow_list))
    f.write('\n')
    
#with open('/path/to/my_file.json', 'w') as f:
    #json.dump(data, f)

# %% [markdown]
# user_list = []
# for i,follower in enumerate(response2['collection']):
#     user_list.append(follower)

# %% [markdown]
# user_list

# %% [markdown]
# num_followers = response.followers_count # Number of reviews you want
# page_order = range(0, (num_followers+1), 50)
# mod_reviews = []
# for ur in start_urls:
#     for o in page_order:
#         page = requests.get(ur + ("?start=%s" % o))
#         tree = html.fromstring(page.text)
#         yp_reviews = tree.xpath('//p[@itemprop="description"]/text()')
#         for rev in yp_reviews:
#             mod_rev = filter(lambda x: x in string.printable, rev)
#             mod_rev = mod_rev.lower()
#             mod_reviews.append(mod_rev)

# %% [markdown]
# followers = client.get('/darien-fields/followers')
# print followers
# for user in followers:
#     print " "
#     print user.id
#     print user.username
#
#
# followers = client.get('me/followers')#.collection
# for user in followers:
#     print(user.obj['username'],user.obj['id'])
